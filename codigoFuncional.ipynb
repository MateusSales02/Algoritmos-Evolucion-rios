# %%
import random

def inicializar_populacao(tamanho_populacao, tamanho_problema):
    # Inicializa a população com indivíduos aleatórios
    return [random.sample(range(100), tamanho_problema) for _ in range(tamanho_populacao)]

def avaliar_populacao(populacao):
    # Avalia a população e retorna a aptidão de cada indivíduo
    return [fitness(ind) for ind in populacao]

def fitness(individuo):
    # Função de fitness - aqui simplesmente somamos os valores do indivíduo
    return sum(individuo)

def obter_melhor_solucao(populacao):
    avaliacoes = avaliar_populacao(populacao)
    return populacao[avaliacoes.index(max(avaliacoes))]

def condicao_de_parada(geracao, max_geracoes):
    return geracao >= max_geracoes

def selecionar_pais(populacao):
    avaliacoes = avaliar_populacao(populacao)
    total = sum(avaliacoes)
    probabilidades = [aval / total for aval in avaliacoes]
    pais = random.choices(populacao, weights=probabilidades, k=len(populacao) // 2)
    return pais

def cruzamento(pai1, pai2, pcrossover):
    if random.random() < pcrossover:
        ponto = random.randint(1, len(pai1) - 1)
        filho1 = pai1[:ponto] + pai2[ponto:]
        filho2 = pai2[:ponto] + pai1[ponto:]
        return filho1, filho2
    return pai1, pai2
def mutar(individuo, pmutacao):
    for i in range(len(individuo)):
        if random.random() < pmutacao:
            individuo[i] = random.randint(0, 100)
    return individuo

def substituir(populacao, filhos):
    return populacao + filhos

def algoritmo_genetico(tamanho_populacao, tamanho_problema, pcrossover, pmutacao, max_geracoes=100):
    populacao = inicializar_populacao(tamanho_populacao, tamanho_problema)
    melhor_solucao = obter_melhor_solucao(populacao)

    geracao = 0
    while not condicao_de_parada(geracao, max_geracoes):
        pais = selecionar_pais(populacao)
        filhos = []

        for i in range(0, len(pais), 2):
            pai1 = pais[i]
            if i + 1 < len(pais):
                pai2 = pais[i + 1]
                filho1, filho2 = cruzamento(pai1, pai2, pcrossover)
                filhos.append(mutar(filho1, pmutacao))
                filhos.append(mutar(filho2, pmutacao))
            else:
                filhos.append(mutar(pai1, pmutacao))

        populacao = substituir(populacao, filhos)
        melhor_solucao = obter_melhor_solucao(populacao)

        geracao += 1
        print(f"Geração {geracao}: Melhor solução até agora: {melhor_solucao}, Fitness: {fitness(melhor_solucao)}")

    return melhor_solucao

tamanho_populacao = 10
tamanho_problema = 5
pcrossover = 0.7
pmutacao = 0.1

resultado = algoritmo_genetico(tamanho_populacao, tamanho_problema, pcrossover, pmutacao)
print("Melhor solução encontrada:", resultado)
# Out:
# Geração 1: Melhor solução até agora: [84, 91, 79, 35, 58], Fitness: 347
# Geração 2: Melhor solução até agora: [84, 91, 79, 35, 58], Fitness: 347
# Geração 3: Melhor solução até agora: [84, 91, 79, 35, 58], Fitness: 347
# Geração 4: Melhor solução até agora: [49, 65, 95, 96, 83], Fitness: 388
# Geração 5: Melhor solução até agora: [49, 65, 95, 96, 83], Fitness: 388
# Geração 6: Melhor solução até agora: [49, 65, 95, 96, 83], Fitness: 388
# Geração 7: Melhor solução até agora: [49, 65, 95, 96, 83], Fitness: 388
# Geração 8: Melhor solução até agora: [49, 65, 95, 96, 83], Fitness: 388
# Geração 9: Melhor solução até agora: [84, 91, 79, 80, 80], Fitness: 414
# Geração 10: Melhor solução até agora: [84, 91, 79, 80, 80], Fitness: 414
# Geração 11: Melhor solução até agora: [84, 91, 79, 89, 88], Fitness: 431
# Geração 12: Melhor solução até agora: [84, 91, 79, 89, 88], Fitness: 431
# Geração 13: Melhor solução até agora: [91, 90, 92, 87, 80], Fitness: 440
# Geração 14: Melhor solução até agora: [91, 90, 92, 87, 80], Fitness: 440
# Geração 15: Melhor solução até agora: [91, 91, 89, 90, 89], Fitness: 450
# Geração 16: Melhor solução até agora: [91, 91, 89, 90, 89], Fitness: 450
# Geração 17: Melhor solução até agora: [99, 97, 95, 98, 76], Fitness: 465
# Geração 18: Melhor solução até agora: [99, 86, 95, 98, 91], Fitness: 469
# Geração 19: Melhor solução até agora: [99, 97, 89, 98, 89], Fitness: 472
# Geração 20: Melhor solução até agora: [99, 86, 95, 98, 99], Fitness: 477
# Geração 21: Melhor solução até agora: [99, 86, 95, 98, 99], Fitness: 477
# Geração 22: Melhor solução até agora: [96, 92, 95, 95, 99], Fitness: 477
# Geração 23: Melhor solução até agora: [96, 92, 95, 95, 99], Fitness: 477
# Geração 24: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 25: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 26: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 27: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 28: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 29: Melhor solução até agora: [99, 99, 99, 91, 99], Fitness: 487
# Geração 30: Melhor solução até agora: [98, 96, 99, 100, 99], Fitness: 492
# Geração 31: Melhor solução até agora: [96, 100, 100, 98, 99], Fitness: 493
# Geração 32: Melhor solução até agora: [96, 100, 100, 98, 99], Fitness: 493
# Geração 33: Melhor solução até agora: [99, 99, 99, 98, 100], Fitness: 495
# Geração 34: Melhor solução até agora: [99, 99, 99, 98, 100], Fitness: 495
# Geração 35: Melhor solução até agora: [99, 100, 99, 99, 100], Fitness: 497
# Geração 36: Melhor solução até agora: [99, 100, 99, 99, 100], Fitness: 497
# Geração 37: Melhor solução até agora: [99, 100, 99, 99, 100], Fitness: 497
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c5b33bb4c846> in <cell line: 77>()
#      75 pmutacao = 0.1
#      76
# ---> 77 resultado = algoritmo_genetico(tamanho_populacao, tamanho_problema, pcrossover, pmutacao)
#      78 print("Melhor solução encontrada:", resultado)
#
# <ipython-input-1-c5b33bb4c846> in algoritmo_genetico(tamanho_populacao, tamanho_problema, pcrossover, pmutacao, max_geracoes)
#      49     geracao = 0
#      50     while not condicao_de_parada(geracao, max_geracoes):
# ---> 51         pais = selecionar_pais(populacao)
#      52         filhos = []
#      53
#
# <ipython-input-1-c5b33bb4c846> in selecionar_pais(populacao)
#      24     total = sum(avaliacoes)
#      25     probabilidades = [aval / total for aval in avaliacoes]
# ---> 26     pais = random.choices(populacao, weights=probabilidades, k=len(populacao) // 2)
#      27     return pais
#      28
#
# /usr/lib/python3.10/random.py in choices(self, population, weights, cum_weights, k)
#     538         bisect = _bisect
#     539         hi = n - 1
# --> 540         return [population[bisect(cum_weights, random() * total, 0, hi)]
#     541                 for i in _repeat(None, k)]
#     542
#
# /usr/lib/python3.10/random.py in <listcomp>(.0)
#     538         bisect = _bisect
#     539         hi = n - 1
# --> 540         return [population[bisect(cum_weights, random() * total, 0, hi)]
#     541                 for i in _repeat(None, k)]
#     542
#
# KeyboardInterrupt:
